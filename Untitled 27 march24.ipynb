# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Model,Sequential, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D,Input
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import DenseNet121

# %%
disease_types=['Apple___Cedar_apple_rust', 'Apple___healthy']
data_dir = 'dataset'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.head()

# %%
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train))
train.head()
# Out:
#                                File  DiseaseID     Disease Type
# 0   Apple___healthy/image (169).JPG          1  Apple___healthy
# 1    Apple___healthy/image (73).JPG          1  Apple___healthy
# 2  Apple___healthy/image (1300).JPG          1  Apple___healthy
# 3  Apple___healthy/image (1213).JPG          1  Apple___healthy
# 4  Apple___healthy/image (1122).JPG          1  Apple___healthy

# %%
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('Apple___Cedar_apple_rust', 5, 5)

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
plot_defects('Apple___healthy', 5, 5)

# %%
IMAGE_SIZE = 64
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath))
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
from tqdm import tqdm
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 1920it [00:06, 296.68it/s]
# Train Shape: (1920, 64, 64, 3)

# %%
from keras.utils import to_categorical
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)

# %%
BATCH_SIZE = 64

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 25
SIZE=64
N_ch=3

# %%
from keras.optimizers import Adam
def build_densenet():
    densenet = DenseNet121(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    
    optimizer = Adam(learning_rate=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    return model

# %%
# Implement early stopping
from keras.callbacks import EarlyStopping

# %%
model = build_densenet()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model1.h5', verbose=1, save_best_only=True)

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360,
                        width_shift_range=0.2,
                        height_shift_range=0.2,
                        zoom_range=0.2,
                        horizontal_flip=True,
                        vertical_flip=True)

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint,early_stopping],
               validation_data=(X_val, Y_val))
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d (Conv2D)             (None, 64, 64, 3)         84
#
#  densenet121 (Functional)    (None, None, None, 1024   7037504
#                              )
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  batch_normalization (Batch  (None, 1024)              4096
#  Normalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 256)               262400
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  root (Dense)                (None, 2)                 514
#
# =================================================================
# Total params: 7305622 (27.87 MB)
# Trainable params: 7219414 (27.54 MB)
# Non-trainable params: 86208 (336.75 KB)
# _________________________________________________________________
# Epoch 1/25
#
# Epoch 1: val_loss improved from inf to 1.21689, saving model to model1.h5
# C:\Users\saiga\anaconda3\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 24/24 - 190s - loss: 1.1861 - accuracy: 0.5332 - val_loss: 1.2169 - val_accuracy: 0.2552 - lr: 0.0020 - 190s/epoch - 8s/step
# Epoch 2/25
#
# Epoch 2: val_loss improved from 1.21689 to 0.58260, saving model to model1.h5
# 24/24 - 130s - loss: 0.8602 - accuracy: 0.6452 - val_loss: 0.5826 - val_accuracy: 0.7161 - lr: 0.0020 - 130s/epoch - 5s/step
# Epoch 3/25
#
# Epoch 3: val_loss did not improve from 0.58260
# 24/24 - 126s - loss: 0.5600 - accuracy: 0.7617 - val_loss: 0.6759 - val_accuracy: 0.6146 - lr: 0.0020 - 126s/epoch - 5s/step
# Epoch 4/25
#
# Epoch 4: val_loss improved from 0.58260 to 0.33009, saving model to model1.h5
# 24/24 - 123s - loss: 0.2962 - accuracy: 0.8809 - val_loss: 0.3301 - val_accuracy: 0.9115 - lr: 0.0020 - 123s/epoch - 5s/step
# Epoch 5/25
#
# Epoch 5: val_loss did not improve from 0.33009
# 24/24 - 121s - loss: 0.1742 - accuracy: 0.9342 - val_loss: 0.3871 - val_accuracy: 0.8411 - lr: 0.0020 - 121s/epoch - 5s/step
# Epoch 6/25
#
# Epoch 6: val_loss improved from 0.33009 to 0.16197, saving model to model1.h5
# 24/24 - 119s - loss: 0.1101 - accuracy: 0.9674 - val_loss: 0.1620 - val_accuracy: 0.9766 - lr: 0.0020 - 119s/epoch - 5s/step
# Epoch 7/25
#
# Epoch 7: val_loss improved from 0.16197 to 0.08571, saving model to model1.h5
# 24/24 - 123s - loss: 0.0862 - accuracy: 0.9733 - val_loss: 0.0857 - val_accuracy: 0.9922 - lr: 0.0020 - 123s/epoch - 5s/step
# Epoch 8/25
#
# Epoch 8: val_loss improved from 0.08571 to 0.04300, saving model to model1.h5
# 24/24 - 128s - loss: 0.0696 - accuracy: 0.9824 - val_loss: 0.0430 - val_accuracy: 1.0000 - lr: 0.0020 - 128s/epoch - 5s/step
# Epoch 9/25
#
# Epoch 9: val_loss improved from 0.04300 to 0.02803, saving model to model1.h5
# 24/24 - 120s - loss: 0.0680 - accuracy: 0.9876 - val_loss: 0.0280 - val_accuracy: 1.0000 - lr: 0.0020 - 120s/epoch - 5s/step
# Epoch 10/25
#
# Epoch 10: val_loss did not improve from 0.02803
# 24/24 - 114s - loss: 0.0765 - accuracy: 0.9837 - val_loss: 0.0287 - val_accuracy: 0.9948 - lr: 0.0020 - 114s/epoch - 5s/step
# Epoch 11/25
#
# Epoch 11: val_loss improved from 0.02803 to 0.02231, saving model to model1.h5
# 24/24 - 116s - loss: 0.0520 - accuracy: 0.9876 - val_loss: 0.0223 - val_accuracy: 0.9974 - lr: 0.0020 - 116s/epoch - 5s/step
# Epoch 12/25
#
# Epoch 12: val_loss improved from 0.02231 to 0.01656, saving model to model1.h5
# 24/24 - 114s - loss: 0.0301 - accuracy: 0.9922 - val_loss: 0.0166 - val_accuracy: 0.9974 - lr: 0.0020 - 114s/epoch - 5s/step
# Epoch 13/25
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 13: val_loss improved from 0.01656 to 0.01527, saving model to model1.h5
# 24/24 - 123s - loss: 0.0349 - accuracy: 0.9935 - val_loss: 0.0153 - val_accuracy: 0.9974 - lr: 0.0020 - 123s/epoch - 5s/step
# Epoch 14/25
#
# Epoch 14: val_loss did not improve from 0.01527
# 24/24 - 120s - loss: 0.0345 - accuracy: 0.9928 - val_loss: 0.0165 - val_accuracy: 0.9974 - lr: 0.0010 - 120s/epoch - 5s/step
# Epoch 15/25
#
# Epoch 15: val_loss did not improve from 0.01527
# 24/24 - 121s - loss: 0.0220 - accuracy: 0.9961 - val_loss: 0.0155 - val_accuracy: 0.9974 - lr: 0.0010 - 121s/epoch - 5s/step
# Epoch 16/25
#
# Epoch 16: val_loss improved from 0.01527 to 0.01461, saving model to model1.h5
# 24/24 - 128s - loss: 0.0249 - accuracy: 0.9974 - val_loss: 0.0146 - val_accuracy: 0.9974 - lr: 0.0010 - 128s/epoch - 5s/step
# Epoch 17/25
#
# Epoch 17: val_loss improved from 0.01461 to 0.01340, saving model to model1.h5
# 24/24 - 128s - loss: 0.0235 - accuracy: 0.9967 - val_loss: 0.0134 - val_accuracy: 0.9974 - lr: 0.0010 - 128s/epoch - 5s/step
# Epoch 18/25
#
# Epoch 18: val_loss improved from 0.01340 to 0.01165, saving model to model1.h5
# 24/24 - 132s - loss: 0.0257 - accuracy: 0.9961 - val_loss: 0.0116 - val_accuracy: 0.9974 - lr: 0.0010 - 132s/epoch - 6s/step
# Epoch 19/25
#
# Epoch 19: val_loss improved from 0.01165 to 0.01029, saving model to model1.h5
# 24/24 - 132s - loss: 0.0177 - accuracy: 0.9974 - val_loss: 0.0103 - val_accuracy: 0.9974 - lr: 0.0010 - 132s/epoch - 6s/step
# Epoch 20/25
#
# Epoch 20: val_loss did not improve from 0.01029
# 24/24 - 123s - loss: 0.0255 - accuracy: 0.9948 - val_loss: 0.0127 - val_accuracy: 0.9974 - lr: 0.0010 - 123s/epoch - 5s/step
# Epoch 21/25
#
# Epoch 21: val_loss did not improve from 0.01029
# 24/24 - 124s - loss: 0.0227 - accuracy: 0.9941 - val_loss: 0.0121 - val_accuracy: 0.9974 - lr: 0.0010 - 124s/epoch - 5s/step
# Epoch 22/25
#
# Epoch 22: val_loss improved from 0.01029 to 0.00611, saving model to model1.h5
# 24/24 - 165s - loss: 0.0157 - accuracy: 0.9967 - val_loss: 0.0061 - val_accuracy: 1.0000 - lr: 0.0010 - 165s/epoch - 7s/step
# Epoch 23/25
#
# Epoch 23: val_loss improved from 0.00611 to 0.00463, saving model to model1.h5
# 24/24 - 132s - loss: 0.0272 - accuracy: 0.9928 - val_loss: 0.0046 - val_accuracy: 1.0000 - lr: 0.0010 - 132s/epoch - 6s/step
# Epoch 24/25
#
# Epoch 24: val_loss improved from 0.00463 to 0.00439, saving model to model1.h5
# 24/24 - 122s - loss: 0.0329 - accuracy: 0.9980 - val_loss: 0.0044 - val_accuracy: 1.0000 - lr: 0.0010 - 122s/epoch - 5s/step
# Epoch 25/25
#
# Epoch 25: val_loss did not improve from 0.00439
# 24/24 - 120s - loss: 0.0183 - accuracy: 0.9967 - val_loss: 0.0067 - val_accuracy: 0.9974 - lr: 0.0010 - 120s/epoch - 5s/step

# %%
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 12/12 [==============================] - 7s 601ms/step - loss: 0.0067 - accuracy: 0.9974
# Final Loss: 0.006727105472236872, Final Accuracy: 0.9973958134651184

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# 12/12 [==============================] - 17s 766ms/step
# Text(0.5, 192.58159722222217, 'Predicted')

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from skimage import io
from keras.preprocessing import image
img = image.load_img('dataset/image01.jpg', grayscale=False, target_size=(64, 64))
show_img=image.load_img('dataset/image01.jpg', grayscale=False, target_size=(200, 200))
disease_class=['Apple___Cedar_apple_rust', 'Apple___healthy']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# 1/1 [==============================] - 0s 94ms/step
# [9.9986517e-01 1.3479083e-04]
# Prediction: Apple___Cedar_apple_rust
